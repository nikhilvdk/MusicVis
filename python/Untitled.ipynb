# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('finaloutput.xlsx')

# %%
genres = df.groupby(['genre']).mean()
genres
# Out:
#                       year     score  best_new_music     pub_year  \
# genre
# Country        2007.357143  7.085714        0.000000  2010.285714
# Electronic     2010.666667  6.542424        0.050505  2011.848485
# Folk           2012.666667  7.022222        0.000000  2013.888889
# Hip-Hop        2010.848101  6.640506        0.037975  2012.000000
# Indie          2012.478261  6.926087        0.108696  2012.456522
# Jazz           2000.083333  7.691667        0.250000  2009.916667
# Metal          2008.896552  7.110345        0.103448  2012.551724
# Not Available  2006.363636  6.845455        0.000000  2011.181818
# Other          2013.150000  7.110000        0.050000  2013.850000
# Pop            2010.485714  6.680952        0.057143  2012.028571
# R&B            2007.000000  7.155556        0.000000  2013.666667
# Rock           2009.592857  6.610714        0.053571  2011.142857
#
#                acousticness  danceability    duration_ms    energy  \
# genre
# ...

# %%
counts = df.groupby(['genre']).count()['song']
counts
# Out:
# genre
# Country           14
# Electronic        99
# Folk               9
# Hip-Hop           79
# Indie             46
# Jazz              12
# Metal             29
# Not Available     11
# Other             20
# Pop              105
# R&B                9
# Rock             280
# Name: song, dtype: int64

# %%
x = genres[['acousticness','danceability','instrumentalness','loudness','tempo','valence']].sort_values(by=['instrumentalness'], ascending=False)

# %%
xnew = x.drop(['Folk','Indie','Metal','Not Available','Other','R&B'])

# %%
xnew
# Out:
#             acousticness  danceability  instrumentalness   loudness  \
# genre
# Jazz            0.599308      0.471167          0.385273 -14.305083
# Electronic      0.270774      0.566061          0.350509  -9.116939
# Rock            0.242227      0.474280          0.168089  -8.094832
# Pop             0.263336      0.531125          0.165655  -8.125533
# Country         0.687500      0.440286          0.071386 -10.952214
# Hip-Hop         0.200995      0.630000          0.067939  -6.825190
#
#                  tempo   valence
# genre
# Jazz        110.939333  0.292533
# Electronic  120.911444  0.374986
# Rock        122.772500  0.472096
# Pop         126.229933  0.451174
# Country     133.895714  0.469071
# Hip-Hop     112.926658  0.525637

# %%
xnew[['acousticness']].plot(kind='bar')

# %%
df = df.drop(df[df.genre=='R&B'].index)

# %%
# Out:
#                                     song  year                    artist  \
# 0                        tennessee blues  1972             bobby charles
# 1                       beautiful people  2010                 the books
# 2                         hisingen blues  2016                 graveyard
# 3                    can you get to that  2009                funkadelic
# 4    god takes care of the little things  2007   the boy least likely to
# 5                     board up the house  2009              genghis tron
# 6                            thank youse  2007  del the funky homosapien
# 7                                 tephra  2014               fear of men
# 8                                 ativan  2016               atlas sound
# 9                                   life  2013          chocolate genius
# 10                              invasion  2010                    george
# 12                        top tim rubies  2007                  deerhoof
# ...

# %%
y = df[['genre','acousticness','danceability','instrumentalness','loudness','tempo','valence']]

# %%
y
# Out:
#           genre  acousticness  danceability  instrumentalness  loudness  \
# 0          Jazz      0.231000         0.487          0.002470   -13.062
# 1    Electronic      0.712000         0.657          0.021700   -10.000
# 2          Rock      0.015700         0.234          0.515000    -5.023
# 3          Rock      0.539000         0.689          0.000000    -8.774
# 4           Pop      0.869000         0.822          0.054600   -13.679
# 5    Electronic      0.000027         0.297          0.817000    -6.279
# 6       Hip-Hop      0.009450         0.834          0.721000    -7.214
# 7           Pop      0.162000         0.422          0.891000    -5.705
# 8    Electronic      0.005440         0.429          0.001460    -6.294
# 9          Rock      0.236000         0.604          0.007140   -12.914
# 10         Rock      0.000226         0.273          0.360000    -9.310
# 12         Rock      0.024700         0.258          0.687000    -4.607
# ...
